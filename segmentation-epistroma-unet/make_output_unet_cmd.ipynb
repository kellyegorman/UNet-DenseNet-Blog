# %% [markdown]
# <a href="https://colab.research.google.com/github/kellyegorman/UNet-DenseNet-Blog/blob/main/segmentation-epistroma-unet/make_output_unet_cmd.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/gdrive')
# %cd /gdrive/MyDrive/PytorchDigitalPathology/segmentation_epistroma_unet
# Out:
# Mounted at /gdrive
# /gdrive/MyDrive/PytorchDigitalPathology/segmentation_epistroma_unet

# %%
import sklearn
import torch
import argparse
import numpy as np
import cv2
import torchvision
from PS_scikitlearn import extract_patches
from unet import UNet
import os, glob

# %%
#-----helper function to split data into batches
def divide_batch(l, n):
    for i in range(0, l.shape[0], n):
        yield l[i:i + n,::]

# %%
# ----- parse command line arguments
parser = argparse.ArgumentParser(description='Make output for entire image using Unet')
parser.add_argument('input_pattern',
                    help="input filename pattern. try: *.png, or tsv file containing list of files to analyze",
                    nargs="*")

parser.add_argument('-p', '--patchsize', help="patchsize, default 256", default=256, type=int)
parser.add_argument('-s', '--batchsize', help="batchsize for controlling GPU memory usage, default 10", default=10, type=int)
parser.add_argument('-o', '--outdir', help="outputdir, default ./output/", default="./output/", type=str)
parser.add_argument('-r', '--resize', help="resize factor 1=1x, 2=2x, .5 = .5x", default=1, type=float)
parser.add_argument('-m', '--model', help="model", default="best_model.pth", type=str)
parser.add_argument('-i', '--gpuid', help="id of gpu to use", default=0, type=int)
parser.add_argument('-f', '--force', help="force regeneration of output even if it exists", default=False,
                    action="store_true")
parser.add_argument('-b', '--basepath',
                    help="base path to add to file names, helps when producing data using tsv file as input",
                    default="", type=str)

# args = parser.parse_args()
args = parser.parse_args(["./data/*.tif","-o./data/output","-m./epistroma_unet_best_model.pth"] )

if not (args.input_pattern):
    parser.error('No images selected with input pattern')

OUTPUT_DIR = args.outdir
resize = args.resize

batch_size = args.batchsize
patch_size = args.patchsize
stride_size = patch_size//2

# %%
# ----- load network
device = torch.device(args.gpuid if torch.cuda.is_available() else 'cpu')

# %%
checkpoint = torch.load(args.model, map_location=lambda storage, loc: storage)
#load checkpoint to CPU and then put to device https://discuss.pytorch.org/t/saving-and-loading-torch-models-on-2-machines-with-different-number-of-gpu-devices/6666
# Out:
# <ipython-input-6-6ef237ad671f>:1: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(args.model, map_location=lambda storage, loc: storage)

# %%
model = UNet(n_classes=checkpoint["n_classes"], in_channels=checkpoint["in_channels"],
             padding=checkpoint["padding"], depth=checkpoint["depth"], wf=checkpoint["wf"],
             up_mode=checkpoint["up_mode"], batch_norm=checkpoint["batch_norm"]).to(device)
model.load_state_dict(checkpoint["model_dict"])
model.eval()

print(f"total params: \t{sum([np.prod(p.size()) for p in model.parameters()])}")
# Out:
# total params: 	122466

# %%
# ----- get file list

if not os.path.exists(OUTPUT_DIR):
    os.makedirs(OUTPUT_DIR)

files = []
basepath = args.basepath  #
basepath = basepath + os.sep if len(
    basepath) > 0 else ""  # if the user supplied a different basepath, make sure it ends with an os.sep

if len(args.input_pattern) > 1:  # bash has sent us a list of files
    files = args.input_pattern
elif args.input_pattern[0].endswith("tsv"):  # user sent us an input file
    # load first column here and store into files
    with open(args.input_pattern[0], 'r') as f:
        for line in f:
            if line[0] == "#":
                continue
            files.append(basepath + line.strip().split("\t")[0])
else:  # user sent us a wildcard, need to use glob to find files
    if len(args.basepath)>=1:
      files = glob.glob(args.basepath +"/"+ args.input_pattern[0])
    else:
      files = glob.glob(args.input_pattern[0])

# %%
# ------ work on files
for fname in files:

    fname = fname.strip()
    newfname_class = "%s/%s_class.png" % (OUTPUT_DIR, os.path.basename(fname)[0:os.path.basename(fname).rfind(".")])

    print(f"working on file: \t {fname}")
    print(f"saving to : \t {newfname_class}")

    if not args.force and os.path.exists(newfname_class):
        print("Skipping as output file exists")
        continue

    cv2.imwrite(newfname_class, np.zeros(shape=(1, 1)))


    io = cv2.cvtColor(cv2.imread(fname),cv2.COLOR_BGR2RGB)
    io = cv2.resize(io, (0, 0), fx=args.resize, fy=args.resize)

    io_shape_orig = np.array(io.shape)

    #add half the stride as padding around the image, so that we can crop it away later
    io = np.pad(io, [(stride_size//2, stride_size//2), (stride_size//2, stride_size//2), (0, 0)], mode="reflect")

    io_shape_wpad = np.array(io.shape)

    #pad to match an exact multiple of unet patch size, otherwise last row/column are lost
    npad0 = int(np.ceil(io_shape_wpad[0] / patch_size) * patch_size - io_shape_wpad[0])
    npad1 = int(np.ceil(io_shape_wpad[1] / patch_size) * patch_size - io_shape_wpad[1])

    io = np.pad(io, [(0, npad0), (0, npad1), (0, 0)], mode="constant")

    arr_out = extract_patches(io,(patch_size,patch_size,3),stride_size)
    arr_out_shape = arr_out.shape
    arr_out = arr_out.reshape(-1,patch_size,patch_size,3)

    #in case we have a large network, lets cut the list of tiles into batches
    output = np.zeros((0,checkpoint["n_classes"],patch_size,patch_size))
    for batch_arr in divide_batch(arr_out,batch_size):

        arr_out_gpu = torch.from_numpy(batch_arr.transpose(0, 3, 1, 2) / 255).type('torch.FloatTensor').to(device)

        # ---- get results
        output_batch = model(arr_out_gpu)

        # --- pull from GPU and append to rest of output
        output_batch = output_batch.detach().cpu().numpy()

        output = np.append(output,output_batch,axis=0)


    output = output.transpose((0, 2, 3, 1))

    #turn from a single list into a matrix of tiles
    output = output.reshape(arr_out_shape[0],arr_out_shape[1],patch_size,patch_size,output.shape[3])

    #remove the padding from each tile, we only keep the center
    output=output[:,:,stride_size//2:-stride_size//2,stride_size//2:-stride_size//2,:]

    #turn all the tiles into an image
    output=np.concatenate(np.concatenate(output,1),1)

    #incase there was extra padding to get a multiple of patch size, remove that as well
    output = output[0:io_shape_orig[0], 0:io_shape_orig[1], :] #remove paddind, crop back

    # --- save output

    # cv2.imwrite(newfname_class, (output.argmax(axis=2) * (256 / (output.shape[-1] - 1) - 1)).astype(np.uint8))
    cv2.imwrite(newfname_class, output.argmax(axis=2) * (256 / (output.shape[-1] - 1) - 1))
# Out:
# working on file: 	 ./data/10258_00006.tif
# saving to : 	 ./data/output/10258_00006_class.png
# working on file: 	 ./data/10277_00006.tif
# saving to : 	 ./data/output/10277_00006_class.png
# working on file: 	 ./data/10262_00025.tif
# saving to : 	 ./data/output/10262_00025_class.png
# working on file: 	 ./data/10269_00022.tif
# saving to : 	 ./data/output/10269_00022_class.png
# working on file: 	 ./data/10276_00037.tif
# saving to : 	 ./data/output/10276_00037_class.png
# working on file: 	 ./data/10260_00022.tif
# saving to : 	 ./data/output/10260_00022_class.png
# working on file: 	 ./data/10261_00002.tif
# saving to : 	 ./data/output/10261_00002_class.png
# working on file: 	 ./data/10256_00003.tif
# saving to : 	 ./data/output/10256_00003_class.png
# working on file: 	 ./data/10275_00099.tif
# saving to : 	 ./data/output/10275_00099_class.png
# working on file: 	 ./data/10264_00056.tif
# saving to : 	 ./data/output/10264_00056_class.png
# working on file: 	 ./data/10274_00004.tif
# saving to : 	 ./data/output/10274_00004_class.png
# working on file: 	 ./data/10273_00095.tif
# saving to : 	 ./data/output/10273_00095_class.png
# working on file: 	 ./data/10259_00002.tif
# saving to : 	 ./data/output/10259_00002_class.png
# working on file: 	 ./data/10257_00026.tif
# saving to : 	 ./data/output/10257_00026_class.png
# working on file: 	 ./data/10254_00001.tif
# saving to : 	 ./data/output/10254_00001_class.png
# working on file: 	 ./data/10282_00016.tif
# saving to : 	 ./data/output/10282_00016_class.png
# working on file: 	 ./data/10301_00026.tif
# saving to : 	 ./data/output/10301_00026_class.png
# working on file: 	 ./data/10292_00018.tif
# saving to : 	 ./data/output/10292_00018_class.png
# working on file: 	 ./data/10288_00003.tif
# saving to : 	 ./data/output/10288_00003_class.png
# working on file: 	 ./data/10279_00049.tif
# saving to : 	 ./data/output/10279_00049_class.png
# working on file: 	 ./data/10302_00098.tif
# saving to : 	 ./data/output/10302_00098_class.png
# working on file: 	 ./data/10293_00011.tif
# saving to : 	 ./data/output/10293_00011_class.png
# working on file: 	 ./data/10291_00012.tif
# saving to : 	 ./data/output/10291_00012_class.png
# working on file: 	 ./data/10285_00007.tif
# saving to : 	 ./data/output/10285_00007_class.png
# working on file: 	 ./data/10278_00006.tif
# saving to : 	 ./data/output/10278_00006_class.png
# working on file: 	 ./data/10299_00154.tif
# saving to : 	 ./data/output/10299_00154_class.png
# working on file: 	 ./data/10286_00014.tif
# saving to : 	 ./data/output/10286_00014_class.png
# working on file: 	 ./data/10295_00012.tif
# saving to : 	 ./data/output/10295_00012_class.png
# working on file: 	 ./data/10304_00005.tif
# saving to : 	 ./data/output/10304_00005_class.png
# working on file: 	 ./data/12752_00004.tif
# saving to : 	 ./data/output/12752_00004_class.png
# working on file: 	 ./data/10303_00090.tif
# saving to : 	 ./data/output/10303_00090_class.png
# working on file: 	 ./data/10307_00004.tif
# saving to : 	 ./data/output/10307_00004_class.png
# working on file: 	 ./data/12819_00004.tif
# saving to : 	 ./data/output/12819_00004_class.png
# working on file: 	 ./data/12820_00005.tif
# saving to : 	 ./data/output/12820_00005_class.png
# working on file: 	 ./data/12811_00008.tif
# saving to : 	 ./data/output/12811_00008_class.png
# working on file: 	 ./data/12818_00006.tif
# saving to : 	 ./data/output/12818_00006_class.png
# working on file: 	 ./data/12626_00016.tif
# saving to : 	 ./data/output/12626_00016_class.png
# working on file: 	 ./data/10308_00048.tif
# saving to : 	 ./data/output/10308_00048_class.png
# working on file: 	 ./data/12749_00010.tif
# saving to : 	 ./data/output/12749_00010_class.png
# working on file: 	 ./data/10306_00018.tif
# saving to : 	 ./data/output/10306_00018_class.png
# working on file: 	 ./data/12900_00008.tif
# saving to : 	 ./data/output/12900_00008_class.png
# working on file: 	 ./data/12906_00017.tif
# saving to : 	 ./data/output/12906_00017_class.png
# working on file: 	 ./data/12821_00018.tif
# saving to : 	 ./data/output/12821_00018_class.png
# working on file: 	 ./data/12882_00026.tif
# saving to : 	 ./data/output/12882_00026_class.png
# working on file: 	 ./data/12881_00009.tif
# saving to : 	 ./data/output/12881_00009_class.png
# working on file: 	 ./data/12875_00002.tif
# saving to : 	 ./data/output/12875_00002_class.png
# working on file: 	 ./data/12822_00002.tif
# saving to : 	 ./data/output/12822_00002_class.png
# working on file: 	 ./data/12867_00005.tif
# saving to : 	 ./data/output/12867_00005_class.png
# working on file: 	 ./data/12880_00001.tif
# saving to : 	 ./data/output/12880_00001_class.png
# working on file: 	 ./data/12901_00005.tif
# saving to : 	 ./data/output/12901_00005_class.png
# working on file: 	 ./data/12826_00003.tif
# saving to : 	 ./data/output/12826_00003_class.png
# working on file: 	 ./data/12884_00018.tif
# saving to : 	 ./data/output/12884_00018_class.png
# working on file: 	 ./data/12891_00006.tif
# saving to : 	 ./data/output/12891_00006_class.png
# working on file: 	 ./data/8914_00006.tif
# saving to : 	 ./data/output/8914_00006_class.png
# working on file: 	 ./data/8915_00001.tif
# saving to : 	 ./data/output/8915_00001_class.png
# working on file: 	 ./data/12929_00017.tif
# saving to : 	 ./data/output/12929_00017_class.png
# working on file: 	 ./data/8951_00005.tif
# saving to : 	 ./data/output/8951_00005_class.png
# working on file: 	 ./data/8916_00005.tif
# saving to : 	 ./data/output/8916_00005_class.png
# working on file: 	 ./data/8913_00002.tif
# saving to : 	 ./data/output/8913_00002_class.png
# working on file: 	 ./data/12934_00025.tif
# saving to : 	 ./data/output/12934_00025_class.png
# working on file: 	 ./data/8864_00024.tif
# saving to : 	 ./data/output/8864_00024_class.png
# working on file: 	 ./data/12948_00001.tif
# saving to : 	 ./data/output/12948_00001_class.png
# working on file: 	 ./data/12932_00003.tif
# saving to : 	 ./data/output/12932_00003_class.png
# working on file: 	 ./data/8918_00007.tif
# saving to : 	 ./data/output/8918_00007_class.png
# working on file: 	 ./data/12909_00003.tif
# saving to : 	 ./data/output/12909_00003_class.png
# working on file: 	 ./data/12930_00008.tif
# saving to : 	 ./data/output/12930_00008_class.png
# working on file: 	 ./data/8867_00011.tif
# saving to : 	 ./data/output/8867_00011_class.png
# working on file: 	 ./data/12947_00004.tif
# saving to : 	 ./data/output/12947_00004_class.png
# working on file: 	 ./data/12911_00005.tif
# saving to : 	 ./data/output/12911_00005_class.png
# working on file: 	 ./data/12931_00010.tif
# saving to : 	 ./data/output/12931_00010_class.png
# working on file: 	 ./data/12907_00003.tif
# saving to : 	 ./data/output/12907_00003_class.png
# working on file: 	 ./data/8865_00002.tif
# saving to : 	 ./data/output/8865_00002_class.png
# working on file: 	 ./data/8956_00011.tif
# saving to : 	 ./data/output/8956_00011_class.png
# working on file: 	 ./data/9043_00045.tif
# saving to : 	 ./data/output/9043_00045_class.png
# working on file: 	 ./data/9022_00008.tif
# saving to : 	 ./data/output/9022_00008_class.png
# working on file: 	 ./data/8957_00005.tif
# saving to : 	 ./data/output/8957_00005_class.png
# working on file: 	 ./data/9081_00008.tif
# saving to : 	 ./data/output/9081_00008_class.png
# working on file: 	 ./data/9041_00008.tif
# saving to : 	 ./data/output/9041_00008_class.png
# working on file: 	 ./data/9037_00009.tif
# saving to : 	 ./data/output/9037_00009_class.png
# working on file: 	 ./data/8974_00014.tif
# saving to : 	 ./data/output/8974_00014_class.png
# working on file: 	 ./data/9083_00022.tif
# saving to : 	 ./data/output/9083_00022_class.png
# working on file: 	 ./data/8975_00017.tif
# saving to : 	 ./data/output/8975_00017_class.png
# working on file: 	 ./data/9024_00001.tif
# saving to : 	 ./data/output/9024_00001_class.png
# working on file: 	 ./data/8959_00013.tif
# saving to : 	 ./data/output/8959_00013_class.png
# working on file: 	 ./data/9076_00005.tif
# saving to : 	 ./data/output/9076_00005_class.png
# working on file: 	 ./data/8980_00013.tif
# saving to : 	 ./data/output/8980_00013_class.png
# working on file: 	 ./data/9123_00005.tif
# saving to : 	 ./data/output/9123_00005_class.png
# working on file: 	 ./data/9023_00012.tif
# saving to : 	 ./data/output/9023_00012_class.png
# working on file: 	 ./data/8955_00018.tif
# saving to : 	 ./data/output/8955_00018_class.png
# working on file: 	 ./data/9029_00010.tif
# saving to : 	 ./data/output/9029_00010_class.png
# working on file: 	 ./data/9078_00011.tif
# saving to : 	 ./data/output/9078_00011_class.png
# working on file: 	 ./data/9073_00007.tif
# saving to : 	 ./data/output/9073_00007_class.png
# working on file: 	 ./data/9178_00010.tif
# saving to : 	 ./data/output/9178_00010_class.png
# working on file: 	 ./data/9261_00019.tif
# saving to : 	 ./data/output/9261_00019_class.png
# working on file: 	 ./data/9255_00011.tif
# saving to : 	 ./data/output/9255_00011_class.png
# working on file: 	 ./data/9254_00013.tif
# saving to : 	 ./data/output/9254_00013_class.png
# working on file: 	 ./data/9228_00003.tif
# saving to : 	 ./data/output/9228_00003_class.png
# working on file: 	 ./data/9173_00049.tif
# saving to : 	 ./data/output/9173_00049_class.png
# working on file: 	 ./data/9259_00017.tif
# saving to : 	 ./data/output/9259_00017_class.png
# working on file: 	 ./data/9227_00006.tif
# saving to : 	 ./data/output/9227_00006_class.png
# working on file: 	 ./data/9257_00012.tif
# saving to : 	 ./data/output/9257_00012_class.png
# working on file: 	 ./data/9176_00024.tif
# saving to : 	 ./data/output/9176_00024_class.png
# working on file: 	 ./data/9250_00025.tif
# saving to : 	 ./data/output/9250_00025_class.png
# working on file: 	 ./data/9181_00013.tif
# saving to : 	 ./data/output/9181_00013_class.png
# working on file: 	 ./data/9175_00001.tif
# saving to : 	 ./data/output/9175_00001_class.png
# working on file: 	 ./data/9225_00002.tif
# saving to : 	 ./data/output/9225_00002_class.png
# working on file: 	 ./data/9125_00005.tif
# saving to : 	 ./data/output/9125_00005_class.png
# working on file: 	 ./data/9124_00021.tif
# saving to : 	 ./data/output/9124_00021_class.png
# working on file: 	 ./data/9177_00004.tif
# saving to : 	 ./data/output/9177_00004_class.png
# working on file: 	 ./data/9174_00001.tif
# saving to : 	 ./data/output/9174_00001_class.png
# working on file: 	 ./data/9256_00054.tif
# saving to : 	 ./data/output/9256_00054_class.png
# working on file: 	 ./data/9126_00056.tif
# saving to : 	 ./data/output/9126_00056_class.png
# working on file: 	 ./data/9323_00021.tif
# saving to : 	 ./data/output/9323_00021_class.png
# working on file: 	 ./data/9382_00020.tif
# saving to : 	 ./data/output/9382_00020_class.png
# working on file: 	 ./data/9346_00019.tif
# saving to : 	 ./data/output/9346_00019_class.png
# working on file: 	 ./data/9383_00006.tif
# saving to : 	 ./data/output/9383_00006_class.png
# working on file: 	 ./data/9322_00006.tif
# saving to : 	 ./data/output/9322_00006_class.png
# working on file: 	 ./data/9345_00065.tif
# saving to : 	 ./data/output/9345_00065_class.png
# working on file: 	 ./data/9267_00024.tif
# saving to : 	 ./data/output/9267_00024_class.png
# working on file: 	 ./data/9290_00006.tif
# saving to : 	 ./data/output/9290_00006_class.png
# working on file: 	 ./data/9265_00001.tif
# saving to : 	 ./data/output/9265_00001_class.png
# working on file: 	 ./data/9266_00002.tif
# saving to : 	 ./data/output/9266_00002_class.png
# working on file: 	 ./data/9381_00010.tif
# saving to : 	 ./data/output/9381_00010_class.png
# working on file: 	 ./data/9347_00011.tif
# saving to : 	 ./data/output/9347_00011_class.png
# working on file: 	 ./data/9320_00011.tif
# saving to : 	 ./data/output/9320_00011_class.png
